# %%
#we can define data frames using dictionarys and lists
p={'name':['ravi','priya','hari','sindu','prash'],'age':[23,12,25,34,28]}
p
# Out:
# {'name': ['ravi', 'priya', 'hari', 'sindu', 'prash'],
#  'age': [23, 12, 25, 34, 28]}

# %%
p['name']
# Out:
# ['ravi', 'priya', 'hari', 'sindu', 'prash']

# %%
p['gender']=['m','f','m','f','m']
p['palce']=['hyd','viz','simla','goa','banglore']
p
# Out:
# {'name': ['ravi', 'priya', 'hari', 'sindu', 'prash'],
#  'age': [23, 12, 25, 34, 28],
#  'gender': ['m', 'f', 'm', 'f', 'm'],
#  'palce': ['hyd', 'viz', 'simla', 'goa', 'banglore']}

# %%
import pandas as pd
a=pd.DataFrame(p)
a
# Out:
#     name  age gender     palce
# 0   ravi   23      m       hyd
# 1  priya   12      f       viz
# 2   hari   25      m     simla
# 3  sindu   34      f       goa
# 4  prash   28      m  banglore

# %%
name=['ravi','priya','hari','sindu','prash']
age=[23,12,25,34,28]
gender=['m','f','m','f','m']
place=['hyd','viz','simla','goa','banglore']
c=list(zip(name,age,gender,place))    #zip is used to give tuple outputs
c
# Out:
# [('ravi', 23, 'm', 'hyd'),
#  ('priya', 12, 'f', 'viz'),
#  ('hari', 25, 'm', 'simla'),
#  ('sindu', 34, 'f', 'goa'),
#  ('prash', 28, 'm', 'banglore')]

# %%
b=pd.DataFrame(c)
b
# Out:
#        0   1  2         3
# 0   ravi  23  m       hyd
# 1  priya  12  f       viz
# 2   hari  25  m     simla
# 3  sindu  34  f       goa
# 4  prash  28  m  banglore

# %%
pd.DataFrame(name)
# Out:
#        0
# 0   ravi
# 1  priya
# 2   hari
# 3  sindu
# 4  prash

# %%
d=[[1,3,4,5],[4,5,6,8]]
pd.DataFrame(d)
# Out:
#    0  1  2  3
# 0  1  3  4  5
# 1  4  5  6  8

# %%
name1=['ravi','priya','hari','sindu','prash']
age1=[23,12,25,34,28]
dict_1={'name':name1,'age':age1}  #using list as values to dictionary
pd.DataFrame(dict_1)
# Out:
#     name  age
# 0   ravi   23
# 1  priya   12
# 2   hari   25
# 3  sindu   34
# 4  prash   28

# %%
list(zip(name1,age1))
# Out:
# [('ravi', 23), ('priya', 12), ('hari', 25), ('sindu', 34), ('prash', 28)]

# %%
d=list(zip(name1,age1))
pd.DataFrame(d,columns=['Name','Age'])
# Out:
#     Name  Age
# 0   ravi   23
# 1  priya   12
# 2   hari   25
# 3  sindu   34
# 4  prash   28

# %%
# ?pd.read_csv

# %%
loan_data=pd.read_csv("C:/Users/MORA.SHIVARAMAKRISHN/Desktop/python_jupiter/Data/loans data.csv")
loan_data
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
loan_data.shape  #to fine the shape of the data frame
# Out:
# (2500, 15)

# %%
type(loan_data)
# Out:
# pandas.core.frame.DataFrame

# %%
loan_data2=pd.read_csv("loans data.csv")  #if we dont give path ...it checks in working directory
loan_data2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-36-2c481d2e0007> in <module>
# ----> 1 loan_data2=pd.read_csv("loans data.csv")  #if we dont give path ...it checks in working directory
#       2 loan_data2
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
pwd  #working directory,
# Out:
# 'C:\\Users\\MORA.SHIVARAMAKRISHN\\Machine_learning\\ML_pyrhon'

# %%
loan_data.head()  #default we get first five rows
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 1   36 months  debt_consolidation               28.36%    TX       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 3   36 months  debt_consolidation               14.30%    KS       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %%
loan_data.head(10)
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 1  99592.0            19200                      19200        12.12%
# 2  80059.0            35000                      35000        21.98%
# 3  15825.0            10000                       9975         9.99%
# 4  33182.0            12000                      12000        11.71%
# 5  62403.0             6000                       6000        15.31%
# 6  48808.0            10000                      10000         7.90%
# 7  22090.0            33500                      33450        17.14%
# 8  76404.0            14675                      14675        14.33%
# 9  15867.0                .                       7000         6.91%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# ...

# %%
loan_data.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'State',
#        'Home.Ownership', 'Monthly.Income', 'FICO.Range', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')

# %%
type(loan_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
list(loan_data.columns)  #converting to lists
# Out:
# ['ID',
#  'Amount.Requested',
#  'Amount.Funded.By.Investors',
#  'Interest.Rate',
#  'Loan.Length',
#  'Loan.Purpose',
#  'Debt.To.Income.Ratio',
#  'State',
#  'Home.Ownership',
#  'Monthly.Income',
#  'FICO.Range',
#  'Open.CREDIT.Lines',
#  'Revolving.CREDIT.Balance',
#  'Inquiries.in.the.Last.6.Months',
#  'Employment.Length']

# %%
loan_data.dtypes  #data types of all columns
# Out:
# ID                                float64
# Amount.Requested                   object
# Amount.Funded.By.Investors         object
# Interest.Rate                      object
# Loan.Length                        object
# Loan.Purpose                       object
# Debt.To.Income.Ratio               object
# State                              object
# Home.Ownership                     object
# Monthly.Income                    float64
# FICO.Range                         object
# Open.CREDIT.Lines                  object
# Revolving.CREDIT.Balance           object
# Inquiries.in.the.Last.6.Months    float64
# Employment.Length                  object
# dtype: object

# %%
loan_data.info()   #to know the summary and null values can be check
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
# ID                                2499 non-null float64
# Amount.Requested                  2499 non-null object
# Amount.Funded.By.Investors        2499 non-null object
# Interest.Rate                     2500 non-null object
# Loan.Length                       2499 non-null object
# Loan.Purpose                      2499 non-null object
# Debt.To.Income.Ratio              2499 non-null object
# State                             2499 non-null object
# Home.Ownership                    2499 non-null object
# Monthly.Income                    2497 non-null float64
# FICO.Range                        2500 non-null object
# Open.CREDIT.Lines                 2496 non-null object
# Revolving.CREDIT.Balance          2497 non-null object
# Inquiries.in.the.Last.6.Months    2497 non-null float64
# Employment.Length                 2422 non-null object
# ...

# %%
loan_data.describe()   #it gives the entire information for float variables
# Out:
#                   ID  Monthly.Income  Inquiries.in.the.Last.6.Months
# count    2499.000000     2497.000000                     2497.000000
# mean    51643.325330     5689.716608                        0.906688
# std     30053.637661     3963.568002                        1.231149
# min        10.000000      588.500000                        0.000000
# 25%     26570.500000     3500.000000                        0.000000
# 50%     50673.000000     5000.000000                        0.000000
# 75%     77583.000000     6800.000000                        1.000000
# max    104202.000000   102750.000000                        9.000000

# %%
loan_data=pd.read_csv("C:/Users/MORA.SHIVARAMAKRISHN/Desktop/python_jupiter/Data/loans data.csv")
loan_data
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
x=loan_data['ID']  #accessing a column in data frame
x
# Out:
# 0       81174.0
# 1       99592.0
# 2       80059.0
# 3       15825.0
# 4       33182.0
#          ...
# 2495    23735.0
# 2496    65882.0
# 2497    55610.0
# 2498    38576.0
# 2499     3116.0
# Name: ID, Length: 2500, dtype: float64

# %%
type(x)  #one column is series in pandas
# Out:
# pandas.core.series.Series

# %%
list(x)  #converting to list
# Out:
# [81174.0,
#  99592.0,
#  80059.0,
#  15825.0,
#  33182.0,
#  62403.0,
#  48808.0,
#  22090.0,
#  76404.0,
#  15867.0,
#  94971.0,
#  36911.0,
#  41200.0,
#  83869.0,
#  53853.0,
#  21399.0,
#  62127.0,
#  23446.0,
#  44987.0,
#  17977.0,
#  86099.0,
#  99483.0,
#  28798.0,
#  24168.0,
#  10356.0,
#  46027.0,
#  2238.0,
#  65278.0,
#  4227.0,
#  50182.0,
#  87023.0,
#  46120.0,
#  30756.0,
#  94582.0,
#  457.0,
#  96536.0,
#  39591.0,
#  78862.0,
#  54619.0,
#  101798.0,
#  98029.0,
#  95579.0,
#  4868.0,
#  26822.0,
#  98445.0,
#  14958.0,
#  14754.0,
#  34501.0,
#  26888.0,
#  81759.0,
#  10825.0,
#  16667.0,
#  92046.0,
#  88279.0,
#  17218.0,
#  82406.0,
#  17143.0,
#  27486.0,
#  96613.0,
#  6263.0,
#  29283.0,
#  99766.0,
#  85893.0,
#  98972.0,
#  44054.0,
#  51948.0,
#  48676.0,
#  82294.0,
#  20328.0,
#  71489.0,
#  43203.0,
#  48319.0,
#  5367.0,
#  83768.0,
#  88084.0,
#  101540.0,
#  9664.0,
#  1494.0,
#  61703.0,
#  61576.0,
#  21993.0,
#  58359.0,
#  67335.0,
# ...

# %%
e=loan_data[['ID','Amount.Requested']] #accessing multiple columns #subsetting means accessing perticular colums or rows
e
# Out:
#            ID Amount.Requested
# 0     81174.0            20000
# 1     99592.0            19200
# 2     80059.0            35000
# 3     15825.0            10000
# 4     33182.0            12000
# ...       ...              ...
# 2495  23735.0            30000
# 2496  65882.0            16000
# 2497  55610.0            10000
# 2498  38576.0             6000
# 2499   3116.0             9000
#
# [2500 rows x 2 columns]

# %%
type(e)  #its a data frame
# Out:
# pandas.core.frame.DataFrame

# %%
loan_data.iloc[:,0]  #accesing first column by index value, iloc is used when we want to subset df useinf index values
# Out:
# 0       81174.0
# 1       99592.0
# 2       80059.0
# 3       15825.0
# 4       33182.0
#          ...
# 2495    23735.0
# 2496    65882.0
# 2497    55610.0
# 2498    38576.0
# 2499     3116.0
# Name: ID, Length: 2500, dtype: float64

# %%
loan_data.iloc[:,0:2]  #accessing two columns at atime
# Out:
#            ID Amount.Requested
# 0     81174.0            20000
# 1     99592.0            19200
# 2     80059.0            35000
# 3     15825.0            10000
# 4     33182.0            12000
# ...       ...              ...
# 2495  23735.0            30000
# 2496  65882.0            16000
# 2497  55610.0            10000
# 2498  38576.0             6000
# 2499   3116.0             9000
#
# [2500 rows x 2 columns]

# %%
loan_data.iloc[:,[0,1,5]]   # to access 1,2,6 columns,we must give as lists
# Out:
#            ID Amount.Requested        Loan.Purpose
# 0     81174.0            20000  debt_consolidation
# 1     99592.0            19200  debt_consolidation
# 2     80059.0            35000  debt_consolidation
# 3     15825.0            10000  debt_consolidation
# 4     33182.0            12000         credit_card
# ...       ...              ...                 ...
# 2495  23735.0            30000  debt_consolidation
# 2496  65882.0            16000    home_improvement
# 2497  55610.0            10000  debt_consolidation
# 2498  38576.0             6000      major_purchase
# 2499   3116.0             9000  debt_consolidation
#
# [2500 rows x 3 columns]

# %%
loan_data.iloc[[0,2,4],:]  #accessing multiple rows
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  81174.0            20000                      20000         8.90%
# 2  80059.0            35000                      35000        21.98%
# 4  33182.0            12000                      12000        11.71%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   36 months  debt_consolidation               14.90%    SC       MORTGAGE
# 2   60 months  debt_consolidation               23.81%    CA       MORTGAGE
# 4   36 months         credit_card               18.78%    NJ           RENT
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# 0         6541.67    735-739                14                    14272
# 2        11500.00    690-694                14                    21977
# 4         3195.00    695-699                11                    14469
#
#    Inquiries.in.the.Last.6.Months Employment.Length
# ...

# %%
loan_data.iloc[[0,2,4],[0,1,4]]  #accessing rows and columns
# Out:
#         ID Amount.Requested Loan.Length
# 0  81174.0            20000   36 months
# 2  80059.0            35000   60 months
# 4  33182.0            12000   36 months

# %%
i=loan_data['Home.Ownership']
i
# Out:
# 0       MORTGAGE
# 1       MORTGAGE
# 2       MORTGAGE
# 3       MORTGAGE
# 4           RENT
#           ...
# 2495    MORTGAGE
# 2496         OWN
# 2497    MORTGAGE
# 2498        RENT
# 2499        RENT
# Name: Home.Ownership, Length: 2500, dtype: object

# %%
s=list(loan_data['Home.Ownership'])
s
# Out:
# ['MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'OWN',
#  'RENT',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'OWN',
#  'MORTGAGE',
#  'RENT',
#  'MORTGAGE',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'OWN',
#  'RENT',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'OWN',
#  'RENT',
#  'MORTGAGE',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'RENT',
#  'OWN',
#  'RENT',
#  'MORTGAGE',
#  'MORTGAGE',
#  'RENT',
#  'OWN',
# ...

# %%
set(s)
# Out:
# {'MORTGAGE', 'NONE', 'OTHER', 'OWN', 'RENT', nan}

# %%
loan_data['Home.Ownership'].unique()  #unique values of a columns
# Out:
# array(['MORTGAGE', 'RENT', 'OWN', 'OTHER', 'NONE', nan], dtype=object)

# %%
loan_data['Home.Ownership'].value_counts()  #to know the freq of levels in a column/variable(freq of unique values)
# Out:
# MORTGAGE    1147
# RENT        1146
# OWN          200
# OTHER          5
# NONE           1
# Name: Home.Ownership, dtype: int64

# %%
loan_data.value_counts()  #value_counts is not applicable for df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-394bb91a7ccc> in <module>
# ----> 1 loan_data.value_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_counts'

# %%
loan_data['Home.Ownership']=='MORTGAGE'  #check whether mortgage is there or not(comparing)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 2495     True
# 2496    False
# 2497     True
# 2498    False
# 2499    False
# Name: Home.Ownership, Length: 2500, dtype: bool

# %%
b
# Out:
#        0   1  2         3
# 0   ravi  23  m       hyd
# 1  priya  12  f       viz
# 2   hari  25  m     simla
# 3  sindu  34  f       goa
# 4  prash  28  m  banglore

# %%
b.iloc[[0,1],:]
# Out:
#        0   1  2    3
# 0   ravi  23  m  hyd
# 1  priya  12  f  viz

# %%
b.iloc[[True,False,True,False,False],:]  #here rows are boolean, iloc is used when we use indeces
# Out:
#       0   1  2      3
# 0  ravi  23  m    hyd
# 2  hari  25  m  simla

# %%
b.loc[[True,False,True,False,False],:]  #this is correct when we use boolean values, loc is used when boolean values are involved
# Out:
#       0   1  2      3
# 0  ravi  23  m    hyd
# 2  hari  25  m  simla

# %%
y=[True,False,True,False,False]
b.loc[:,y]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-51321094362e> in <module>
#       1 y=[True,False,True,False,False]
# ----> 2 b.loc[:,y]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     820                 continue
#     821
# --> 822             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     823
#     824         return retval
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
# ...

# %%
y=[True,False,True,False]
b.loc[:,y]
# Out:
#        0  2
# 0   ravi  m
# 1  priya  f
# 2   hari  m
# 3  sindu  f
# 4  prash  m

# %%
v=loan_data[loan_data['Home.Ownership']=='MORTGAGE']
v
#pd.DataFrame(v)
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 7     22090.0            33500                      33450        17.14%
# ...       ...              ...                        ...           ...
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
# 2497  55610.0            10000                      10000        13.99%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
v.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-2e7aea03a539> in <module>
# ----> 1 v.unique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
v['Home.Ownership'].unique
# Out:
# <bound method Series.unique of 0       MORTGAGE
# 1       MORTGAGE
# 2       MORTGAGE
# 3       MORTGAGE
# 7       MORTGAGE
#           ...
# 2492    MORTGAGE
# 2493    MORTGAGE
# 2494    MORTGAGE
# 2495    MORTGAGE
# 2497    MORTGAGE
# Name: Home.Ownership, Length: 1147, dtype: object>

# %%
t=loan_data[loan_data['Home.Ownership']=='MORTGAGE']

dk=t[t['Monthly.Income']>5000]
dk
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 2     80059.0            35000                      35000        21.98%
# 7     22090.0            33500                      33450        17.14%
# 12    41200.0            28000                      27975        21.67%
# 20    86099.0            22000                      21975        21.98%
# ...       ...              ...                        ...           ...
# 2485  13070.0            25000                      24950        10.75%
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio Home.Ownership  \
# ...

# %%
k=dk
k.reset_index(inplace=True)  #here previous index is also mention so we use drop argument
k
# Out:
#      index       ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0        0  81174.0            20000                      20000         8.90%
# 1        2  80059.0            35000                      35000        21.98%
# 2        7  22090.0            33500                      33450        17.14%
# 3       12  41200.0            28000                      27975        21.67%
# 4       20  86099.0            22000                      21975        21.98%
# ..     ...      ...              ...                        ...           ...
# 681   2485  13070.0            25000                      24950        10.75%
# 682   2492    925.0             6400                       6350        10.08%
# 683   2493  74047.0            30000                      30000        23.28%
# 684   2494  49957.0            24000                      23975        14.65%
# 685   2495  23735.0            30000                      29950        16.77%
#
# ...

# %%
dk.reset_index(inplace=True,drop=True)  #drop is used to erase the previous index value
dk  #in python index are rows indeces as default  so no need to mention axis value
# Out:
#           ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0    81174.0            20000                      20000         8.90%
# 1    80059.0            35000                      35000        21.98%
# 2    22090.0            33500                      33450        17.14%
# 3    41200.0            28000                      27975        21.67%
# 4    86099.0            22000                      21975        21.98%
# ..       ...              ...                        ...           ...
# 681  13070.0            25000                      24950        10.75%
# 682    925.0             6400                       6350        10.08%
# 683  74047.0            30000                      30000        23.28%
# 684  49957.0            24000                      23975        14.65%
# 685  23735.0            30000                      29950        16.77%
#
#     Loan.Length        Loan.Purpose Debt.To.Income.Ratio Home.Ownership  \
# ...

# %%
r=loan_data
r[(r['Home.Ownership']=='MORTGAGE') &(r['Monthly.Income']>5000)]
#r[(r['Home.Ownership']=='MORTGAGE') and  (r['Monthly.Income']>5000) ]
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 2     80059.0            35000                      35000        21.98%
# 7     22090.0            33500                      33450        17.14%
# 12    41200.0            28000                      27975        21.67%
# 20    86099.0            22000                      21975        21.98%
# ...       ...              ...                        ...           ...
# 2485  13070.0            25000                      24950        10.75%
# 2492    925.0             6400                       6350        10.08%
# 2493  74047.0            30000                      30000        23.28%
# 2494  49957.0            24000                      23975        14.65%
# 2495  23735.0            30000                      29950        16.77%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
j=dk['Monthly.Income']  #cross checking for the above process
j
j.min()
# Out:
# 5002.33

# %%
loan_data.drop('State',axis=1,inplace=True)  #inplace is to save back the operation to the loan_data

# %%
loan_data.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'Home.Ownership',
#        'Monthly.Income', 'FICO.Range', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')
