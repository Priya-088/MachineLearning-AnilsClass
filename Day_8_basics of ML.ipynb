# %%
import pandas as pd
import numpy as np

# %%
loan_data=pd.read_csv("C:/Users/MORA.SHIVARAMAKRISHN/Desktop/python_jupiter/Data/loans data.csv")
loan_data
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
loan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 15 columns):
# ID                                2499 non-null float64
# Amount.Requested                  2499 non-null object
# Amount.Funded.By.Investors        2499 non-null object
# Interest.Rate                     2500 non-null object
# Loan.Length                       2499 non-null object
# Loan.Purpose                      2499 non-null object
# Debt.To.Income.Ratio              2499 non-null object
# State                             2499 non-null object
# Home.Ownership                    2499 non-null object
# Monthly.Income                    2497 non-null float64
# FICO.Range                        2500 non-null object
# Open.CREDIT.Lines                 2496 non-null object
# Revolving.CREDIT.Balance          2497 non-null object
# Inquiries.in.the.Last.6.Months    2497 non-null float64
# Employment.Length                 2422 non-null object
# ...

# %%
loan_data.loc[loan_data['Monthly.Income'].isnull()]
# Out:
#             ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 366   101596.0             5000                       4525         7.43%
# 632    45980.0             4800                       4800         7.90%
# 1325   73863.0             4000                       4000         6.03%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# 366    36 months               other                   1%    NY
# 632          NaN  debt_consolidation               19.07%    OH
# 1325   36 months                 car               33.67%   NaN
#
#      Home.Ownership  Monthly.Income FICO.Range Open.CREDIT.Lines  \
# 366            NONE             NaN    800-804               NaN
# 632            RENT             NaN    720-724                12
# 1325       MORTGAGE             NaN    800-804                19
#
#      Revolving.CREDIT.Balance  Inquiries.in.the.Last.6.Months  \
# 366                       NaN                             NaN
# ...

# %%
loan_data.loc[loan_data['Monthly.Income'].isnull(),'Monthly.Income']=

# %%
df=loan_data[~(loan_data['Monthly.Income'].isnull())] #
df
# Out:
#            ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0     81174.0            20000                      20000         8.90%
# 1     99592.0            19200                      19200        12.12%
# 2     80059.0            35000                      35000        21.98%
# 3     15825.0            10000                       9975         9.99%
# 4     33182.0            12000                      12000        11.71%
# ...       ...              ...                        ...           ...
# 2495  23735.0            30000                      29950        16.77%
# 2496  65882.0            16000                      16000        14.09%
# 2497  55610.0            10000                      10000        13.99%
# 2498  38576.0             6000                       6000        12.42%
# 2499   3116.0             9000                    5242.75        13.79%
#
#      Loan.Length        Loan.Purpose Debt.To.Income.Ratio State  \
# ...

# %%
df['Monthly.Income']
# Out:
# 0        6541.67
# 1        4583.33
# 2       11500.00
# 3        3833.33
# 4        3195.00
#           ...
# 2495     9250.00
# 2496     8903.25
# 2497     2166.67
# 2498     3500.00
# 2499     3875.00
# Name: Monthly.Income, Length: 2497, dtype: float64

# %%
x=list(df['Monthly.Income'])  #mean
s=0
for i in x:
    s=s+i
mean=s/(len(x))
mean
# Out:
# 5689.716607929515

# %%
df['Monthly.Income'].mean()
# Out:
# 5689.716607929515

# %%
var=0  #variance
for i in x:
    var=((i-mean)**2)/(len(x))+var
var
# Out:
# 15703579.811100602

# %%
df['Monthly.Income'].var()
# Out:
# 15709871.309422353

# %%
import math  #sandard deviation
sd=math.sqrt(15709871)
sd
# Out:
# 3963.5679633380832

# %%
x
# Out:
# [588.5,
#  666.67,
#  833.33,
#  866.67,
#  884.9,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1083.33,
#  1084.0,
#  1100.0,
#  1100.0,
#  1100.0,
#  1125.0,
#  1200.0,
#  1200.0,
#  1200.0,
#  1250.0,
#  1280.0,
#  1300.0,
#  1312.08,
#  1333.33,
#  1375.0,
#  1403.33,
#  1416.67,
#  1471.0,
#  1482.92,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1541.67,
#  1558.33,
#  1558.42,
#  1560.0,
#  1600.0,
#  1600.0,
#  1600.0,
#  1600.0,
#  1650.0,
#  1658.0,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1667.0,
#  1675.0,
#  1700.0,
#  1700.0,
#  1733.33,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1779.17,
#  1800.0,
#  1800.0,
#  1800.0,
#  1820.0,
#  1833.33,
#  1833.33,
#  1833.33,
#  1833.33,
#  1833.33,
#  1916.67,
#  1916.67,
#  1916.67,
#  1916.67,
#  1930.75,
#  1940.0,
#  1945.0,
#  1958.33,
#  2000.0,
#  2000.0,
# ...

# %%
x.sort()  #process for median calculation,first we sort and will known the middle most index value and access it
x
# Out:
# [588.5,
#  666.67,
#  833.33,
#  866.67,
#  884.9,
#  1000.0,
#  1000.0,
#  1000.0,
#  1000.0,
#  1083.33,
#  1084.0,
#  1100.0,
#  1100.0,
#  1100.0,
#  1125.0,
#  1200.0,
#  1200.0,
#  1200.0,
#  1250.0,
#  1280.0,
#  1300.0,
#  1312.08,
#  1333.33,
#  1375.0,
#  1403.33,
#  1416.67,
#  1471.0,
#  1482.92,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1500.0,
#  1541.67,
#  1558.33,
#  1558.42,
#  1560.0,
#  1600.0,
#  1600.0,
#  1600.0,
#  1600.0,
#  1650.0,
#  1658.0,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1666.67,
#  1667.0,
#  1675.0,
#  1700.0,
#  1700.0,
#  1733.33,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1750.0,
#  1779.17,
#  1800.0,
#  1800.0,
#  1800.0,
#  1820.0,
#  1833.33,
#  1833.33,
#  1833.33,
#  1833.33,
#  1833.33,
#  1916.67,
#  1916.67,
#  1916.67,
#  1916.67,
#  1930.75,
#  1940.0,
#  1945.0,
#  1958.33,
#  2000.0,
#  2000.0,
# ...

# %%
len(x)
len(x)/2  #index of middle value
# Out:
# 1248.5

# %%
median=x[1249]  #median
median
# Out:
# 5000.0

# %%
if mean>median:
    print('right skewed')
if mean<median:
    print('left skewed')
if mean==median:
    print('normal distribution')
# Out:
# right skewed

# %%
#for 1SD deviation, find how much data is present in one standard deviation
z=mean-sd
y=mean+sd
print(z)
y
# Out:
# 1726.1486445914315
# 9653.284571267599

# %%
r=df.loc[(df['Monthly.Income']>=z) & (df['Monthly.Income']<=y),'Monthly.Income']
r
# Out:
# 0       6541.67
# 1       4583.33
# 3       3833.33
# 4       3195.00
# 5       4891.67
#          ...
# 2495    9250.00
# 2496    8903.25
# 2497    2166.67
# 2498    3500.00
# 2499    3875.00
# Name: Monthly.Income, Length: 2205, dtype: float64

# %%
2205/len(df)  #lyptokoitic distribution
# Out:
# 0.8830596716059271

# %%
df['Monthly.Income'].quantile(0.25)
# Out:
# 3500.0

# %%
df['Monthly.Income'].quantile(0.5)
# Out:
# 5000.0

# %%
df['Monthly.Income'].quantile(0.75)
# Out:
# 6800.0

# %%
#here median is near to q1,hence it is right skewed
